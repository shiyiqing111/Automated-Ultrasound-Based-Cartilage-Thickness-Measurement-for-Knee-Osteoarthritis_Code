# %%
import pydicom
from PIL import Image
import numpy as np

print("✅ 环境配置成功！")
print("pydicom 版本：", pydicom.__version__)
# Out:
# ✅ 环境配置成功！
# pydicom 版本： 3.0.1

# %%
import pydicom
import matplotlib.pyplot as plt

filename = "C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series/Abbey 001/v5/contralateral_3 (1)"
ds = pydicom.dcmread(filename)

print("图像尺寸：", ds.Rows, "x", ds.Columns)
plt.imshow(ds.pixel_array, cmap="gray")
plt.title("DICOM 图像显示")
plt.axis("off")
plt.show()
# Out:
# 图像尺寸： 1080 x 1440
# C:\Users\Charlotte\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Charlotte\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20687 (\N{CJK UNIFIED IDEOGRAPH-50CF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Charlotte\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26174 (\N{CJK UNIFIED IDEOGRAPH-663E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Charlotte\anaconda3\envs\py310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 31034 (\N{CJK UNIFIED IDEOGRAPH-793A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import os
import pydicom
import numpy as np
from PIL import Image

root_dir = "C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series"

def is_dicom_file(filepath):
    try:
        with open(filepath, 'rb') as f:
            return f.read(132)[128:132] == b'DICM'
    except:
        return False

def dcm_to_jpg(dcm_path, jpg_path):
    try:
        ds = pydicom.dcmread(dcm_path, force=True)
        arr = ds.pixel_array.astype(float)
        scaled = (np.maximum(arr, 0) / arr.max()) * 255.0
        img = Image.fromarray(np.uint8(scaled))
        img.save(jpg_path, "JPEG")
        return True
    except Exception as e:
        print(f"❌ 转换失败: {dcm_path} -> {e}")
        return False

for root, dirs, files in os.walk(root_dir):
    for file in files:
        file_path = os.path.join(root, file)
        # 判断是否是 DICOM 文件（即使没有后缀）
        if is_dicom_file(file_path):
            jpg_path = os.path.splitext(file_path)[0] + ".jpg"
            if dcm_to_jpg(file_path, jpg_path):
                os.remove(file_path)
                print(f"✅ 已转换并删除: {file_path}")
            else:
                print(f"⚠️ 跳过未成功的文件: {file_path}")

print("🎉 所有 DICOM 文件（包含无后缀）已转换为 JPG。")
# Out:
# ✅ 已转换并删除: C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series\Abbey 001\v5\contralateral_3 (1)
# ✅ 已转换并删除: C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series\Abbey 001\v5\contralateral_3 (2)
# ✅ 已转换并删除: C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series\Abbey 001\v5\contralateral_3 (3)
# ✅ 已转换并删除: C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series\Abbey 001\v5\contralateral_3 (4)
# ✅ 已转换并删除: C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series\Abbey 001\v5\treat_3 (5)
# ✅ 已转换并删除: C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series\Abbey 001\v5\treat_3 (6)
# ✅ 已转换并删除: C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series\Abbey 001\v5\treat_3 (7)
# ✅ 已转换并删除: C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series\Abbey 001\v5\treat_3 (8)
# ✅ 已转换并删除: C:/Users/Charlotte/Desktop/dissertation/US/20251009/Aixplorer_Series\Abbey 002\v5\contralateral_5 (1)
# ...
